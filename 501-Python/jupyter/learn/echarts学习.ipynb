# %%
import pandas as pd 
df=pd.DataFrame([
    ['a','b','c','d'],
    ['1','2','3','4'],
],
    columns=['A','B','C','D'])
print(df)

df_dict=df.to_dict(orient='dict')
print('df_dict',df_dict)

df_list=df.to_dict(orient='list')
print('df_list',df_list)

df_series=df.to_dict(orient='series')
print('df_series',df_series)

df_split=df.to_dict(orient='split')
print('df_split',df_split)

df_records=df.to_dict(orient='records')
print('df_records',df_records)

df_index=df.to_dict(orient='index')
print('df_index',df_index)
# Out:
#    A  B  C  D
# 0  a  b  c  d
# 1  1  2  3  4
# df_dict {'A': {0: 'a', 1: '1'}, 'B': {0: 'b', 1: '2'}, 'C': {0: 'c', 1: '3'}, 'D': {0: 'd', 1: '4'}}
# df_list {'A': ['a', '1'], 'B': ['b', '2'], 'C': ['c', '3'], 'D': ['d', '4']}
# df_series {'A': 0    a
# 1    1
# Name: A, dtype: object, 'B': 0    b
# 1    2
# Name: B, dtype: object, 'C': 0    c
# 1    3
# Name: C, dtype: object, 'D': 0    d
# 1    4
# Name: D, dtype: object}
# df_split {'index': [0, 1], 'columns': ['A', 'B', 'C', 'D'], 'data': [['a', 'b', 'c', 'd'], ['1', '2', '3', '4']]}
# df_records [{'A': 'a', 'B': 'b', 'C': 'c', 'D': 'd'}, {'A': '1', 'B': '2', 'C': '3', 'D': '4'}]
# df_index {0: {'A': 'a', 'B': 'b', 'C': 'c', 'D': 'd'}, 1: {'A': '1', 'B': '2', 'C': '3', 'D': '4'}}

# %%
import pandas as pd 
df=pd.DataFrame([ ['a','b','c','d'], ['1','2','3','4'], ], columns=['A','B','C','D']) 
print(df) 
df_dict=df.set_index('A')['B'].to_dict() 
print(df_dict)
# Out:
#    A  B  C  D
# 0  a  b  c  d
# 1  1  2  3  4
# {'a': 'b', '1': '2'}

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Grid, Line, Liquid, Page, Pie
from pyecharts.commons.utils import JsCode
from pyecharts.components import Table
from pyecharts.faker import Faker
import pandas as pd

def bar_datazoom_slider(xaxis,yaxis_name,yaxis) -> Bar:
   
    if isinstance(yaxis_name,str):
            c=(
        Bar()
        .add_xaxis(xaxis)
        .add_yaxis(yaxis_name,yaxis)
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-DataZoom（slider-水平）"),
            datazoom_opts=[opts.DataZoomOpts()],
        )
    )
    elif isinstance(yaxis,list):
        if len(yaxis_name)==2:
              c=(
        Bar()
        .add_xaxis(xaxis)
        .add_yaxis(yaxis_name[0],yaxis[0])
        .add_yaxis(yaxis_name[1],yaxis[1])
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-DataZoom（slider-水平）"),
            datazoom_opts=[opts.DataZoomOpts()],
        )
    )
            
  
    
    return c

def table_base(header,row) -> Table:
    table = Table()
    headers = header
    rows = row
    table.add(headers, rows).set_global_opts(
        title_opts=opts.ComponentTitleOpts(title="Table")
    )
    return table
name=r'D:\JGY\600-Data\002-in输入文件\个人\孔令手机通信录.xlsx'
#df=pd.read_excel(name,engine='openpyxl')
#df1=df[['姓名','手机','单位','职务']].head(5)
#df_split=df1.to_dict(orient='split')
#tb=table_base(df_split['columns'],df_split['data'])
#tb.render_notebook()

xaxis=['1','2','3']
yaxis_name=['测试','1']
yaxis_name='测试'
yaxis=[1,2,3]
b=bar_datazoom_slider(xaxis,yaxis_name,yaxis)
b.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="410e3a75e91347e2826b402921f9f447" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_410e3a75e91347e2826b402921f9f447 = echarts.init(
#                     document.getElementById('410e3a75e91347e2826b402921f9f447'), 'white', {renderer: 'canvas'});
#                 var option_410e3a75e91347e2826b402921f9f447 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6d4b\u8bd5",
#             "legendHoverLink": true,
#             "data": [
#                 1,
#                 2,
#                 3
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6d4b\u8bd5"
#             ],
#             "selected": {
#                 "\u6d4b\u8bd5": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "1",
#                 "2",
#                 "3"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-DataZoom\uff08slider-\u6c34\u5e73\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false,
#             "filterMode": "filter"
#         }
#     ]
# };
#                 chart_410e3a75e91347e2826b402921f9f447.setOption(option_410e3a75e91347e2826b402921f9f447);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Grid, Line, Liquid, Page, Pie
from pyecharts.commons.utils import JsCode
from pyecharts.components import Table
from pyecharts.faker import Faker
import pandas as pd

def bar_datazoom_slider(xaxis,yaxis_name,yaxis,title_name) -> Bar:
   
    if isinstance(yaxis_name,str):
            c=(
        Bar()
        .add_xaxis(xaxis)
        .add_yaxis(yaxis_name,yaxis)
        .set_global_opts(
            title_opts=opts.TitleOpts(title=title_name),
            datazoom_opts=[opts.DataZoomOpts()],
            brush_opts=opts.BrushOpts(),
            toolbox_opts=opts.ToolboxOpts(),
            legend_opts=opts.LegendOpts(is_show=False),
            yaxis_opts=opts.AxisOpts(name="我是 Y 轴"),
            xaxis_opts=opts.AxisOpts(name="我是 X 轴"),
        )
    )
    elif isinstance(yaxis,list):
        c=Bar()
        c.add_xaxis(xaxis)
        for i in range(len(yaxis_name)):
            c.add_yaxis(yaxis_name[i],yaxis[i], gap="0%",category_gap="10%",is_selected=True)
        c.set_global_opts(
            title_opts=opts.TitleOpts(title=title_name),
            datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside")],
            #datazoom_opts=opts.DataZoomOpts(orient="vertical"),
            brush_opts=opts.BrushOpts(),
            toolbox_opts=opts.ToolboxOpts(),
            legend_opts=opts.LegendOpts(is_show=False),
            yaxis_opts=opts.AxisOpts(name="我是 Y 轴"),
            xaxis_opts=opts.AxisOpts(name="我是 X 轴"),
        )
        c.set_series_opts(
        label_opts=opts.LabelOpts(is_show=True),
        markpoint_opts=opts.MarkPointOpts(
            data=[
                opts.MarkPointItem(type_="max", name="最大值"),
                opts.MarkPointItem(type_="min", name="最小值"),
                opts.MarkPointItem(type_="average", name="平均值"),
            ]
        )
        )              
  
    
    return c

xaxis=['2019年','2020年','2021年']
yaxis_name=['测试1','测试2','测试3']
#yaxis_name='测试'
yaxis=[[1,2,3],[4,5,6],[7,8,9]]
b=bar_datazoom_slider(xaxis,yaxis_name,yaxis,'孔令编制')
b.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9c566f8053eb416683f516a4ebefa79e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9c566f8053eb416683f516a4ebefa79e = echarts.init(
#                     document.getElementById('9c566f8053eb416683f516a4ebefa79e'), 'white', {renderer: 'canvas'});
#                 var option_9c566f8053eb416683f516a4ebefa79e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6d4b\u8bd51",
#             "legendHoverLink": true,
#             "data": [
#                 1,
#                 2,
#                 3
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "10%",
#             "barGap": "0%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u6d4b\u8bd52",
#             "legendHoverLink": true,
#             "data": [
#                 4,
#                 5,
#                 6
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "10%",
#             "barGap": "0%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u6d4b\u8bd53",
#             "legendHoverLink": true,
#             "data": [
#                 7,
#                 8,
#                 9
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "10%",
#             "barGap": "0%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6d4b\u8bd51",
#                 "\u6d4b\u8bd52",
#                 "\u6d4b\u8bd53"
#             ],
#             "selected": {
#                 "\u6d4b\u8bd51": true,
#                 "\u6d4b\u8bd52": true,
#                 "\u6d4b\u8bd53": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "name": "\u6211\u662f X \u8f74",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2019\u5e74",
#                 "2020\u5e74",
#                 "2021\u5e74"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u6211\u662f Y \u8f74",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Grid, Line, Liquid, Page, Pie
from pyecharts.commons.utils import JsCode
from pyecharts.components import Table
from pyecharts.faker import Faker
import pandas as pd
def table_base(header,row) -> Table:
    table = Table(page_title='未完成项')
    headers = header
    rows = row
    table.add(headers, rows).set_global_opts(
        title_opts=opts.ComponentTitleOpts(title="Table")
    )
    return table
name=r'D:\JGY\600-Data\002-in输入文件\个人\孔令手机通信录.xlsx'
df=pd.read_excel(name,engine='openpyxl')
df1=df[['姓名','手机','单位','职务']].head(5)
df_split=df1.to_dict(orient='split')

tb=table_base(df_split['columns'],df_split['data'])
tb.render_notebook()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-ed8317fce15e> in <module>
#      23 df_split=df1.to_dict(orient='split')
#      24
# ---> 25 tb=table_base(df_split['columns'],df_split['data'])
#      26 tb.render_notebook()
#
# <ipython-input-4-ed8317fce15e> in table_base(header, row)
#       6 import pandas as pd
#       7 def table_base(header,row) -> Table:
# ----> 8     table = Table(init_opts=opts.InitOpts(
#       9             js_host=r"D:\JGY\600-Data\004-auxiliary辅助文件\\",
#      10             width="1200px", height="600px",
#
# TypeError: __init__() got an unexpected keyword argument 'init_opts'

# %%
def table_base(header,row) -> Table:
    table = Table()
    headers = header
    rows = row
    table.add(headers, rows).set_global_opts(
        title_opts=opts.ComponentTitleOpts(title="Table")
    )
    return table
name=r'D:\JGY\600-Data\002-in输入文件\个人\孔令手机通信录.xlsx'
df=pd.read_excel(name,engine='openpyxl')
df1=df[['姓名','手机','单位','职务']].head(5)
df_split=df1.to_dict(orient='split')
print(df_split)
tb=table_base(df_split['columns'],df_split['data'])
tb.render_notebook()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-da1aee19c41d> in <module>
# ----> 1 def table_base(header,row) -> Table:
#       2     table = Table()
#       3     headers = header
#       4     rows = row
#       5     table.add(headers, rows).set_global_opts(
#
# NameError: name 'Table' is not defined

# %%
from pyecharts import options as opts
from pyecharts.charts import Gauge
c = (
#Gauge(init_opts=opts.InitOpts(width="1200px", height="600px"))#设置画布尺寸
Gauge(init_opts=opts.InitOpts(js_host = r"D:\JGY\600-Data\004-auxiliary辅助文件"))
.add("", 
     [("完成率", 81.23)],
     title_label_opts=opts.LabelOpts(
            font_size=40, color="blue", font_family="Microsoft YaHei"
        ), 
     radius="50%")
    
.set_global_opts(title_opts=opts.TitleOpts(title="立行立改问题库完成率"))
#.set_global_opts(
#        legend_opts=opts.LegendOpts(is_show=False),
#        tooltip_opts=opts.TooltipOpts(is_show=True, formatter="{a} <br/>{b} : {c}%"),
#    )
#.render("gauge_change_radius.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="856feb4e716042138f6bb74399357983" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_856feb4e716042138f6bb74399357983 = echarts.init(
#                     document.getElementById('856feb4e716042138f6bb74399357983'), 'white', {renderer: 'canvas'});
#                 var option_856feb4e716042138f6bb74399357983 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "position": "top",
#                 "color": "blue",
#                 "margin": 8,
#                 "fontSize": 40,
#                 "fontFamily": "Microsoft YaHei"
#             },
#             "detail": {
#                 "show": true,
#                 "backgroundColor": "transparent",
#                 "borderWidth": 0,
#                 "borderColor": "transparent",
#                 "offsetCenter": [
#                     0,
#                     "-40%"
#                 ],
#                 "formatter": "{value}%",
#                 "color": "auto",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 15,
#                 "borderRadius": 0,
#                 "padding": 0,
#                 "shadowColor": "transparent",
#                 "shadowBlur": 0,
#                 "shadowOffsetX": 0,
#                 "shadowOffsetY": 0
#             },
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "radius": "50%",
#             "startAngle": 225,
#             "endAngle": -45,
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 81.23
#                 }
#             ],
#             "pointer": {
#                 "show": true,
#                 "length": "80%",
#                 "width": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u7acb\u884c\u7acb\u6539\u95ee\u9898\u5e93\u5b8c\u6210\u7387",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_856feb4e716042138f6bb74399357983.setOption(option_856feb4e716042138f6bb74399357983);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Gauge
c = (
#Gauge(init_opts=opts.InitOpts(width="1200px", height="600px"))#设置画布尺寸
Gauge(init_opts=opts.InitOpts(js_host = r"D:\JGY\600-Data\004-auxiliary辅助文件"))
.add("", 
     [("完成率", 81.23)],
     title_label_opts=opts.LabelOpts(
            font_size=40, color="blue", font_family="Microsoft YaHei"
        ), 
     radius="50%")
    
.set_global_opts(title_opts=opts.TitleOpts(title="立行立改问题库完成率"))
#.set_global_opts(
#        legend_opts=opts.LegendOpts(is_show=False),
#        tooltip_opts=opts.TooltipOpts(is_show=True, formatter="{a} <br/>{b} : {c}%"),
#    )
#.render("gauge_change_radius.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="529c5f62eddb4f9890268dd3d0ed4c5d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_529c5f62eddb4f9890268dd3d0ed4c5d = echarts.init(
#                     document.getElementById('529c5f62eddb4f9890268dd3d0ed4c5d'), 'white', {renderer: 'canvas'});
#                 var option_529c5f62eddb4f9890268dd3d0ed4c5d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "position": "top",
#                 "color": "blue",
#                 "margin": 8,
#                 "fontSize": 40,
#                 "fontFamily": "Microsoft YaHei"
#             },
#             "detail": {
#                 "show": true,
#                 "backgroundColor": "transparent",
#                 "borderWidth": 0,
#                 "borderColor": "transparent",
#                 "offsetCenter": [
#                     0,
#                     "-40%"
#                 ],
#                 "formatter": "{value}%",
#                 "color": "auto",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 15,
#                 "borderRadius": 0,
#                 "padding": 0,
#                 "shadowColor": "transparent",
#                 "shadowBlur": 0,
#                 "shadowOffsetX": 0,
#                 "shadowOffsetY": 0
#             },
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "radius": "50%",
#             "startAngle": 225,
#             "endAngle": -45,
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 81.23
#                 }
#             ],
#             "pointer": {
#                 "show": true,
#                 "length": "80%",
#                 "width": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u7acb\u884c\u7acb\u6539\u95ee\u9898\u5e93\u5b8c\u6210\u7387",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_529c5f62eddb4f9890268dd3d0ed4c5d.setOption(option_529c5f62eddb4f9890268dd3d0ed4c5d);
#         });
#     </script>
