# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
bar = (
    Bar()
    .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子"])
    .add_yaxis("商家A", [5,20,15,2], category_gap="90%",color="#ec0000")
    .add_yaxis("商家B", [20,10,5,13], category_gap="90%",color="#675bba")
    .add_yaxis("商家C", [15,20,5,3], category_gap="90%",color="#000")
    .add_yaxis("商家D", [10,15,5,20], category_gap="50%",color="#f46d43")
    .set_global_opts(title_opts=opts.TitleOpts(title="商品主标题A", subtitle="商品副标题B"))
 
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0a4f72a4501143dfbac41e5226826314" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0a4f72a4501143dfbac41e5226826314 = echarts.init(
#                     document.getElementById('0a4f72a4501143dfbac41e5226826314'), 'white', {renderer: 'canvas'});
#                 var option_0a4f72a4501143dfbac41e5226826314 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#f46d43",
#         "#000",
#         "#675bba",
#         "#ec0000",
#         "#c23531",
#         "#2f4554",
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Gauge, Page
c = (
    Gauge()
    .add("", [("完成率", 66.6)])
    .set_global_opts(title_opts=opts.TitleOpts(title="Gauge-基本示例"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="186cfa8ea4aa4019bff62bc3a7fe6de4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_186cfa8ea4aa4019bff62bc3a7fe6de4 = echarts.init(
#                     document.getElementById('186cfa8ea4aa4019bff62bc3a7fe6de4'), 'white', {renderer: 'canvas'});
#                 var option_186cfa8ea4aa4019bff62bc3a7fe6de4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts.charts import Bar
from pyecharts.faker import Faker
from pyecharts.globals import ThemeType

c = (
    Bar({"theme": ThemeType.MACARONS})
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(
        title_opts={"text": "Bar-通过 dict 进行配置", "subtext": "我也是通过 dict 进行配置"}
    )
    #.render("bar_base_dict_config.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'macarons':'https://assets.pyecharts.org/assets/themes/macarons'
#         }
#     });
# </script>
#
#         <div id="d0b9ee4b00c84cf9ac609dd45d3512d5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'macarons'], function(echarts) {
#                 var chart_d0b9ee4b00c84cf9ac609dd45d3512d5 = echarts.init(
#                     document.getElementById('d0b9ee4b00c84cf9ac609dd45d3512d5'), 'macarons', {renderer: 'canvas'});
#                 var option_d0b9ee4b00c84cf9ac609dd45d3512d5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
# ...

# %%
import json
import os
 
from pyecharts import options as opts
from pyecharts.charts import Graph, Page
nodes = [
        {"name": "结点1", "symbolSize": 10},
        {"name": "结点2", "symbolSize": 20},
        {"name": "结点3", "symbolSize": 30},
        {"name": "结点4", "symbolSize": 40},
        {"name": "结点5", "symbolSize": 50},
        {"name": "结点6", "symbolSize": 40},
        {"name": "结点7", "symbolSize": 30},
        {"name": "结点8", "symbolSize": 20},
]
links = []
for i in nodes:
    for j in nodes:
        links.append({"source": i.get("name"), "target": j.get("name")})
c = (
    Graph()
    .add("", nodes, links, repulsion=8000)
    .set_global_opts(title_opts=opts.TitleOpts(title="Graph-基本示例"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2b5c6d2b8485464991b0d306208f6cd1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2b5c6d2b8485464991b0d306208f6cd1 = echarts.init(
#                     document.getElementById('2b5c6d2b8485464991b0d306208f6cd1'), 'white', {renderer: 'canvas'});
#                 var option_2b5c6d2b8485464991b0d306208f6cd1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie

c = (
    Pie()
    .add_dataset(
        source=[
            ["product", "2012", "2013", "2014", "2015", "2016", "2017"],
            ["Matcha Latte", 41.1, 30.4, 65.1, 53.3, 83.8, 98.7],
            ["Milk Tea", 86.5, 92.1, 85.7, 83.1, 73.4, 55.1],
            ["Cheese Cocoa", 24.1, 67.2, 79.5, 86.4, 65.2, 82.5],
            ["Walnut Brownie", 55.2, 67.1, 69.2, 72.4, 53.9, 39.1],
        ]
    )
    .add(
        series_name="Matcha Latte",
        data_pair=[],
        radius=60,
        center=["25%", "30%"],
        encode={"itemName": "product", "value": "2012"},
    )
    .add(
        series_name="Milk Tea",
        data_pair=[],
        radius=60,
        center=["75%", "30%"],
        encode={"itemName": "product", "value": "2013"},
    )
    .add(
        series_name="Cheese Cocoa",
        data_pair=[],
        radius=60,
        center=["25%", "75%"],
        encode={"itemName": "product", "value": "2014"},
    )
    .add(
        series_name="Walnut Brownie",
        data_pair=[],
        radius=60,
        center=["75%", "75%"],
        encode={"itemName": "product", "value": "2015"},
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Dataset simple pie example"),
        legend_opts=opts.LegendOpts(pos_left="30%", pos_top="2%"),
    )
   # .render("dataset_pie.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dc30458eb18c483eb712d2d1f7e55170" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dc30458eb18c483eb712d2d1f7e55170 = echarts.init(
#                     document.getElementById('dc30458eb18c483eb712d2d1f7e55170'), 'white', {renderer: 'canvas'});
#                 var option_dc30458eb18c483eb712d2d1f7e55170 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
import pypinyin
import pandas as pd


# 不带声调的(style=pypinyin.NORMAL)
def pinyin_c(word):
    s = ''
    for i in pypinyin.pinyin(word, style=pypinyin.NORMAL):
        s += ''.join(i).capitalize()+ " "
    return s


# 不带声调的(style=pypinyin.NORMAL)
def pinyin(word):
    s = ''
    for i in pypinyin.pinyin(word, style=pypinyin.NORMAL):
        s += ''.join(i)
    return s

# 带声调的(默认)
def yinjie(word):
    s = ''
    # heteronym=True开启多音字
    for i in pypinyin.pinyin(word, heteronym=True):
        s = s + ''.join(i).capitalize() + " "
    return s


if __name__ == "__main__":
    file_name=r'D:\JGY\600-Data\002-in输入文件\个人\人员信息.xlsx'
    save_name=r'D:\JGY\600-Data\002-in输入文件\个人\人员信息1.xlsx'
    df=pd.read_excel(file_name,engine='openpyxl')
    print(pinyin("孔令"))
    print(pinyin_c("孔令"))
    print(yinjie("孔令"))
    print(yinjie("刘媛媛"))
# Out:
# kongling
# Kong Ling
# Kǒng Lìnglínglǐnglián
# Liú Yuànyuán Yuànyuán

# %%
import pandas as pd
df=pd.DataFrame([
                [1,2,3],
                [3,4,5],
                [3,5,6],
                [3,6,7],
                ],
                #index=[0,1],
                columns=['列1','列2','列3']
                )
dfn=pd.DataFrame({'列1':[1,3,3,3],
                  '列2':[2,4,5,6],
                  '列3':[3,5,6,7],                 
                  },
               
                #index=[0,1],
                
                )

print(df)
print(df.loc[0])
print(df.loc[0,:])
print(df.loc[0:2,'列1'])
print(df.loc[:,'列1':'列3'])
print(df.loc[:,['列1','列3']])
print(df.loc[[0,3],['列1','列3']])
print(df.loc[df['列1']==1,:])

print(df.iloc[0,:])
print(df.iloc[0:2,:])
print(df.iloc[:,0])

df1=df.loc[df['列1']==1,['列2','列1']]
df2=df.loc[df['列1']==1,:]
# Out:
#    列1  列2  列3
# 0   1   2   3
# 1   3   4   5
# 2   3   5   6
# 3   3   6   7
# 列1    1
# 列2    2
# 列3    3
# Name: 0, dtype: int64
# 列1    1
# 列2    2
# 列3    3
# Name: 0, dtype: int64
# 0    1
# 1    3
# 2    3
# Name: 列1, dtype: int64
#    列1  列2  列3
# 0   1   2   3
# 1   3   4   5
# 2   3   5   6
# 3   3   6   7
#    列1  列3
# 0   1   3
# 1   3   5
# 2   3   6
# 3   3   7
#    列1  列3
# 0   1   3
# 3   3   7
#    列1  列2  列3
# 0   1   2   3
# 列1    1
# 列2    2
# 列3    3
# Name: 0, dtype: int64
#    列1  列2  列3
# 0   1   2   3
# 1   3   4   5
# 0    1
# 1    3
# 2    3
# 3    3
# Name: 列1, dtype: int64

# %%
import re
#提取邮箱
pattern = re.compile(r"[a-zA-Z0-9_-]+@[a-zA-Z0-9_-]+(?:\.[a-zA-Z0-9_-]+)")
strs = '我的私人邮箱是zhuwjwh@outlook.com，公司邮箱是123456@qq.org，麻烦登记一下？'
result = pattern.findall(strs)

#提取身份证号
pattern = re.compile(r"[1-9]\d{5}(?:18|19|(?:[23]\d))\d{2}(?:(?:0[1-9])|(?:10|11|12))(?:(?:[0-2][1-9])|10|20|30|31)\d{3}[0-9Xx]")

strs = '小明的身份证号码是342623198910235163，手机号是+8619987692110'
result1 = pattern.findall(strs)


#提取手机号
pattern = re.compile(r"\D(?:86)?0?1[356789]\d{9}")
result2 = pattern.findall(strs)
#提取手机号

pattern=re.compile('\+?(?:86)?0?1[356789]\\d{9}')
result3 = pattern.findall(strs)

#匹配固定电话
pattern = re.compile(r"\d{3}-\d{8}|\d{4}-\d{7}")
strs = '0511-1234567是小明家的电话，他的办公室电话是021-87654321'
result4 = pattern.findall(strs)


pattern = re.compile(r"[\u4e00-\u9fa5]")
strs = 'apple：苹果'
result5 = pattern.findall(strs)


temp='1mobileNo：245996度d\nmobileNo：神东'
findword = u"mobileNo(.*)"#提取字符后数据
pattern = re.compile(findword)  
results6 = pattern.findall(temp)  
print(result1)
print(result2)
print(result3)
print(result4)
print(result5)
print(results6)
# Out:
# ['342623198910235163']
# ['+8619987692110']
# ['19891023516', '+8619987692110']
# ['0511-1234567', '021-87654321']
# ['苹', '果']
# ['：245996度d', '：神东']

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
bar = (
    Bar()
    .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子"])
    .add_yaxis("商家A", [5,20,15,2], category_gap="100%",color="#ec0000")
    .add_yaxis("商家B", [20,10,5,13], category_gap="100%",color="#675bba")
    .add_yaxis("商家C", [15,20,5,3], category_gap="90%",color="#000")
    .add_yaxis("商家D", [10,15,5,20], category_gap="50%",color="#f46d43")
    .set_global_opts(title_opts=opts.TitleOpts(title="商品主标题A", subtitle="商品副标题B"))
 
)

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ec00ba8310d44a3c87e73e1cc09d1829" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ec00ba8310d44a3c87e73e1cc09d1829 = echarts.init(
#                     document.getElementById('ec00ba8310d44a3c87e73e1cc09d1829'), 'white', {renderer: 'canvas'});
#                 var option_ec00ba8310d44a3c87e73e1cc09d1829 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#f46d43",
#         "#000",
#         "#675bba",
#         "#ec0000",
#         "#c23531",
#         "#2f4554",
# ...
