# %% [markdown]
# # pandas数据分析类
# ## 类名称：pandasAnalysis
# ### 函数：
# __init__(self,df)
# get_df(self) 类型pd.DataFrame
# cleaning(self,df,blank=None) 类型pd.DataFrame
# sort_list(self,obj,list_sort,column=None) 类型pd.DataFrame或类型pd.Series
# split_record(self,df: pd.DataFrame, sp_cloc: str, sign: str)类型pd.DataFrame
# plus_record(self,dfp: pd.DataFrame, pr_cloc: str, sign: str)类型pd.DataFrame

# %%
import pandas as pd
class pandasAnalysis():
     # __doc__内容
    """
    作者：1979令狐冲
    E-mail：klmtldh@163.com
    
    pandas数据分析类
    类名称：pandasAnalysis
    函数：
        __init__(self,df)
        get_df(self) 返回类型pd.DataFrame
        cleaning(self,df,blank=None) 类返回型pd.DataFrame
        sort_list(self,obj,list_sort,column=None) 返回类型pd.DataFrame或类型pd.Series
        split_record(self,df: pd.DataFrame, sp_cloc: str, sign: str)返回类型pd.DataFrame
        plus_record(self,dfp: pd.DataFrame, pr_cloc: str, sign: str)返回类型pd.DataFrame
        split_period(self,df, start, end, interval)返回类型pd.DataFrame
        plus_period(self,dfp: pd.DataFrame, s_date,e_date,pr_cloc: str, sign: str)返回类型pd.DataFrame
        
    使用方法：
        1.实例化
        import pandas as pd
        import pandasAnalysis as pa
        df=pd.DataFrame(
                        [
                            ['A','B','C',pd.to_datetime('2020-12-31'),pd.to_datetime('2021-1-8'),'完成情况1'],
                            ['D','E','F',pd.to_datetime('2021-2-26'),pd.to_datetime('2021-3-7'),'完成情况2'],
                            ['C','E','F',pd.to_datetime('2021-1-20'),pd.to_datetime('2022-3-8'),'完成情况3'],
                        ],columns=['编号','责任人','关键任务','开始日期','结束日期','完成情况'])
        df_pa=pa.pandasAnalysis(df)
        2.get_df(self)函数
        获取df值，封装内部数据
        
    """
    def __init__(self,df):
        self.df=df
            
    def get_df(self):
        return self.df
   
    #数据清洗，主要删除重复值，删除缺失值，删除空格
    def cleaning(self,df,blank=None):
        # 删除重复值
        df.drop_duplicates(inplace=True)
        # 删除缺失值
        df.dropna(axis=0, how='all', inplace=True)
        # 删除空格
        if blank=='both':
            df=df.applymap((lambda x:str.strip(x) if type(x) is str else x))
        elif blank=='all':
            df=df.applymap((lambda x:"".join(x.split()) if type(x) is str else x))
        else:
            pass
        return df
    #按照指定列及list排序，可以实现Series和DataFrame,也可以实现排序list少数排序列的值。
    def sort_list(self,obj,list_sort,column=None):
        if isinstance(obj,pd.Series):
            df=pd.DataFrame(obj)
            df = df.reset_index()
            df.columns = ['index', 'values']
            df1=df[df['index'].isin(list_sort)].copy()
            df2=df[~df['index'].isin(list_sort)].copy()
            df1['index']=df1['index'].astype('category')
            df1['index'].cat.set_categories(list_sort, inplace=True)
            df1.sort_values('index', ascending=True, inplace=True)
            df=pd.concat([df1,df2])
            object_ = pd.Series(df['values'].values,index = df['index'])
        elif isinstance(obj,pd.DataFrame):
            obj1=obj[obj[column].isin(list_sort)].copy()
            obj2=obj[~obj[column].isin(list_sort)].copy()
            obj1[column]=obj1[column].astype('category')
            obj1[column].cat.set_categories(list_sort, inplace=True)
            object_=obj1.sort_values(column, ascending=True)
            object_=pd.concat([object_,obj2])
        return object_
    
    def split_record(self,df: pd.DataFrame, sp_cloc: str, sign: str):
        # 记录原始dataframe的长度，并作为后面追加数据的基准
        df.reset_index(inplace=True,drop=True)
        y = len(df)
        # 记录原始dataframe的长度
        len_df = len(df)
        for i in range(len(df)):
            # 将需要分列的列数据按照sign分列出来
            #print(i,df.loc[i, sp_cloc])
            list_str = str.split(df.loc[i, sp_cloc], sign)
            # 依据分列出来数据增加行
            for j in range(len(list_str)):
                y = y + j
                # 复制i行数据
                df.loc[y] = df.loc[i]
                # 将y行数据sp_cloc列数据设置为list_str中数据
                df.loc[y, sp_cloc] = list_str[j]
            y = y + 1
        # 取出新增加数据
        df = df.tail(len(df) - len_df)
        # 重置index
        df = df.reset_index(drop=True)
        return df


    # 将某列以外都相同的行以','进行合并
    def plus_record(self,dfp: pd.DataFrame, pr_cloc: str, sign: str):
        # 获取dfp的列名
        list_cl = list(dfp)
        # 去除需要合并列的列名
        list_cl.remove(pr_cloc)
        # 按照去除合并列名进行排序
        dfp.sort_values(list_cl, inplace=True)
        # 按照排序后行，重新设置index
        dfp = dfp.reset_index(drop=True)
        # 复制dfp，用以处理
        dfpc = dfp.copy()
        # 去除合并列
        dfpc.drop([pr_cloc], axis=1, inplace=True)
        # 进行查重处理
        list_dp = dfpc.duplicated()
        # 查找重复分界点
        x = list_dp[list_dp.isin([False])].index
        # 因为没有找到index插入的方法，将分界点index转为list
        list_x = []
        for q in range(len(x)):
            list_x.append(x[q])
        # 主要用于加入最后一条记录index
        list_x.append(len(dfp))

        # print(list_x)
        # x.append(int64(len(dfp)))
        yn = []
        # 循环获取重复记录段数据
        for i in range(len(list_x) - 1):
            # 判断是否有需要合并项
            if (list_x[i + 1] - list_x[i]) > 1:
                # 若有序号间隔大于1，则进入循环
                for j in range(list_x[i + 1] - list_x[i]):
                    # 取出需要合并数据，形成list
                    yn.append(dfp.loc[list_x[i] + j, pr_cloc])
                # 将list合并成以sign为分隔字符串。
                y = sign.join(yn)
                # 将字符串赋给dfp第一列
                dfp.loc[list_x[i], pr_cloc] = y
                # 删除多余项目
                for k in range(list_x[i + 1] - list_x[i] - 1):
                    dfp.drop(list_x[i] + 1 + k, axis=0, inplace=True)
                # 清空记录list
                yn = []
        # 重置index
        dfp = dfp.reset_index(drop=True)

        return dfp

    def get_n_day(self,date_time, n=1, m=0):
        # this_month_start = datetime.datetime(self.date_time.year, self.date_time.month, 1)
        this_month_nday = datetime.datetime(date_time.year, date_time.month, n)  # +datetime.timedelta(days=n)
        this_month_end = datetime.datetime(date_time.year, date_time.month,
                                           calendar.monthrange(date_time.year, date_time.month)[1])
        # n_month_start=this_month_start +relativedelta(months=m)
        n_month_end = this_month_end + relativedelta(months=m)
        n_month_nday = this_month_nday + relativedelta(months=m)
        return n_month_nday, n_month_end

    def get_current_week(self,date_time, n=1,w=0):
        monday, sunday = date_time, date_time
        one_day = datetime.timedelta(days=1)
        while monday.weekday() != 0:
            monday -= one_day
        while sunday.weekday() != 6:
            sunday += one_day
        # 返回当前的星期一和星期天的日期
        week_n = monday + datetime.timedelta(days=n)
        n_week_end = sunday + relativedelta(weeks=w)
        n_week_nday = week_n + relativedelta(weeks=w)
        return n_week_nday,n_week_end


    def split_period(self,df, start, end, interval):
        #重置df.index，保证后面编号不覆盖。
        df=df.reset_index(drop=True)
        #确定有几行
        df_scope = len(df)
        #遍历所有行
        for i in range(df_scope):
            #判断时间行是时间类型
            if isinstance(df[start][i], datetime.datetime) and isinstance(df[end][i],datetime.datetime):
                #将开始时间行赋值给变量d_start;结束时间赋值给d_end。
                d_start = df[start][i]
                d_end = df[end][i]
                #判断间隔值是m——月；w——月；d——日
                if interval == 'm':                                    
                    delta = rrule.rrule(rrule.MONTHLY, dtstart=d_start, until=d_end).count()
                    #解决跨月问题只要月份不同就判定为跨月
                    if self.get_n_day(df[start][i],m=delta-1)[1]< df[end][i]:
                        delta=delta+1
                    loop_delta = 0
                    if delta > 1:
                        loop_delta = delta
                        for j in range(loop_delta):
                            df_scope = j + df_scope
                            df.loc[df_scope] = df.loc[i]
                            #this_month_start,this_month_end = get_n_day(df[start][df_scope])   
                            if j == 0:                            
                                df.loc[df_scope, end] = self.get_n_day(df[start][df_scope])[1]
                            elif j == loop_delta-1:
                                df.loc[df_scope, start] = self.get_n_day(df[start][df_scope],m=j)[0]
                            else:
                                df.loc[df_scope, start],df.loc[df_scope, end] = self.get_n_day(df[start][df_scope],m=j)
                        df.drop(index=[i], inplace=True)
                    df_scope = df_scope + 1
                 #判断间隔值是m——月；w——周；d——日
                if interval == 'w':
                    delta = rrule.rrule(rrule.WEEKLY, dtstart=d_start, until=d_end).count()
                    #解决跨周问题,关键点是开始日期所在周推delta个周后的周末是否小于end日期              
                    if self.get_current_week(df[start][i], w=delta-1)[1]< df[end][i]:
                        delta=delta+1
                    else:
                        pass               

                    loop_delta = 0
                    if delta > 1:
                        loop_delta = delta
                        for j in range(loop_delta):
                            df_scope = j + df_scope
                            df.loc[df_scope] = df.loc[i]
                            if j == 0:                            
                                df.loc[df_scope, end ] = self.get_current_week(df[start][df_scope])[1]
                            elif j == loop_delta-1:
                                df.loc[df_scope, start] = self.get_current_week(df[start][df_scope],w=j)[0]


                            else:
                                df.loc[df_scope, start],df.loc[df_scope, end]= self.get_current_week(df[start][df_scope],w=j)

                        df.drop(index=[i], inplace=True)
                    df_scope = df_scope + 1
                if interval == 'd':
                    delta = rrule.rrule(rrule.DAILY, dtstart=d_start, until=d_end).count()
                    loop_delta = 0
                    if delta > 1:
                        loop_delta = delta
                        for j in range(loop_delta):
                            df_scope = j + df_scope
                            df.loc[df_scope] = df.loc[i]
                            df.loc[df_scope, start] = d_start + relativedelta(days=+j)
                            df.loc[df_scope, end] = d_start + relativedelta(days=+j)
                        df.drop(index=[i], inplace=True)
                    df_scope = df_scope + 1
        df.reset_index(inplace=True,drop=True)
        return df

    # 将某列以外都相同的行,按照时间','进行合并
    def plus_period(self,dfp: pd.DataFrame, s_date,e_date,pr_cloc: str, sign: str):
        # 获取dfp的列名
        list_cl = list(dfp)
        # 去除需要合并列的列名
        list_cl.remove(s_date)
        list_cl.remove(e_date)
        list_cl.remove(pr_cloc)       
        # 按照去除合并列名进行排序
        dfp.sort_values(list_cl, inplace=True)
        # 按照排序后行，重新设置index
        dfp = dfp.reset_index(drop=True)
        # 复制dfp，用以处理
        dfpc = dfp.copy()
        # 去除合并列
        dfpc.drop([s_date,e_date,pr_cloc], axis=1, inplace=True)
        # 进行查重处理
        list_dp = dfpc.duplicated()
        # 查找重复分界点
        x = list_dp[list_dp.isin([False])].index
        # 因为没有找到index插入的方法，将分界点index转为list
        list_x = []
        for q in range(len(x)):
            list_x.append(x[q])
        # 主要用于加入最后一条记录index
        list_x.append(len(dfp))

        # print(list_x)
        # x.append(int64(len(dfp)))
        yn = []
        # 循环获取重复记录段数据
        for i in range(len(list_x) - 1):
            # 判断是否有需要合并项
            if (list_x[i + 1] - list_x[i]) > 1:
                # 若有序号间隔大于1，则进入循环

                for j in range(list_x[i + 1] - list_x[i]):
                    # 取出需要合并数据，形成list
                    yn.append(dfp.loc[list_x[i] + j, pr_cloc])
                # 将list合并成以sign为分隔字符串。
                y = sign.join(yn)               
                #排序
                dfp_d=dfp.loc[list_x[i]:list_x[i+1]-1,:].copy()            
                dfp_d.sort_values(s_date, inplace=True)
                dfp_d.reset_index(drop=True,inplace=True)
                # 将字符串赋给dfp第一列
                dfp.loc[list_x[i], pr_cloc] = y
                dfp.loc[list_x[i], s_date] = dfp_d.loc[0, s_date]
                dfp.loc[list_x[i], e_date] = dfp_d.loc[list_x[i + 1] - list_x[i]-1, e_date]

                # 删除多余项目
                for k in range(list_x[i + 1] - list_x[i] - 1):
                    dfp.drop(list_x[i] + 1 + k, axis=0, inplace=True)
                # 清空记录list
                yn = []
        # 重置index
        dfp = dfp.reset_index(drop=True)

        return dfp
    
    
    def pandas_text(self,obj,drop_list=None,index_name=None,unit='项',punctuation=[',','。']):
    tx=''
    if isinstance(obj,pd.Series):        
        text = ''
        for i in range(len(obj)):
            if i != len(obj) - 1:
                text += str(obj.index[i]) +' '+ str(obj[i]) + unit + punctuation[0]
            else:
                text += str(obj.index[i])+' ' + str(obj[i]) + unit + punctuation[1]
        text=str(obj.name)+'：'+text
        tx=text
        
    if isinstance(obj,pd.DataFrame):
        text_list=[]
        if index_name is  None:
            
            for column in df.iteritems():
                if column[0] not in drop_list:
                    text = ''
                    for i in range(len(column[1])):
                        if i != len(column[1]) - 1:
                            text += str(column[1].index[i]) +' '+ str(column[1][i]) + unit + punctuation[0]
                        else:
                            text += str(column[1].index[i])+' ' + str(column[1][i]) + unit + punctuation[1]
                        #print('列名'+column[0],'\n',column[1])
                    text=str(column[1].name)+'：'+text
                    text_list.append(text)
        else:
            df.set_index(index_name,drop=True,inplace=True)
            for column in df.iteritems():
                if column[0] not in drop_list:
                    text = ''
                    for i in range(len(column[1])):
                        if i != len(column[1]) - 1:
                            text += str(column[1].index[i]) +' '+ str(column[1][i]) + unit + punctuation[0]
                        else:
                            text += str(column[1].index[i])+' ' + str(column[1][i]) + unit + punctuation[1]
                        #print('列名'+column[0],'\n',column[1])
                    text=str(column[1].name)+'：'+text
                    text_list.append(text)
            
            
        tx=text_list
    return tx
    
if __name__ == '__main__':
    print(pandasAnalysis.__doc__)
    df=pd.DataFrame(
                [
                    ['A','孔令、刘 媛媛 ','C',pd.to_datetime('2020-12-31'),pd.to_datetime('2021-1-8'),'完成情况1'],
                    ['D','李 黎、李进 、昆 明','F',pd.to_datetime('2021-2-26'),pd.to_datetime('2021-3-7'),'完成情况2'],
                    ['C','王 玺','F',pd.to_datetime('2021-1-20'),pd.to_datetime('2022-3-8'),'完成情况3'],
                ],columns=['编号','责任人','关键任务','开始日期','结束日期','完成情况'])

    pa=pandasAnalysis(df)
    df1= pa.cleaning(pa.get_df())
    df2= pa.cleaning(pa.get_df(),'both')
    df3= pa.cleaning(pa.get_df(),'all')
    print(df)
    print(pa.get_df())
    print(df1)
    print(df2)
    print(df3)
    ls=['D','A','B','C']
    df4=pa.sort_list(df3,ls,'编号')
    print(df4)
    df5=pa.split_record(df4,'责任人','、')
    print(df5)
    df6=pa.plus_record(df5, '责任人',  '，')
    print(df6)
    df7=pd.DataFrame(
    [
        ['A','B','C',pd.to_datetime('2020-12-31'),pd.to_datetime('2021-1-8'),'完成情况1'],
        ['D','E','F',pd.to_datetime('2021-2-26'),pd.to_datetime('2021-3-7'),'完成情况2'],
        ['C','E','F',pd.to_datetime('2021-1-20'),pd.to_datetime('2022-3-8'),'完成情况3'],
    ]
    ,columns=['编号','责任人','关键任务','开始日期','结束日期','完成情况'])
    print(df7)
    df8=pa.split_period(df7, '开始日期', '结束日期', 'm')
    print(df8)
    df9=pa.plus_period(df8, '开始日期', '结束日期','完成情况', '；')
    print(df9)
    path=r"D:\JGY\300-Work工作\320-PM项目管理\电网年度运行方式\2021年昆明电网八大运行风险防控措施分解表（审查稿).xlsx"
    df_risk=pd.read_excel(path,'一、主保护、稳控装置拒动导致电网稳定破坏风险',engine="openpyxl")
    print(df_risk.head)
# Out:
#     作者：1979令狐冲
#     E-mail：klmtldh@163.com
#
#     pandas数据分析类
#     类名称：pandasAnalysis
#     函数：
#         __init__(self,df)
#         get_df(self) 返回类型pd.DataFrame
#         cleaning(self,df,blank=None) 类返回型pd.DataFrame
#         sort_list(self,obj,list_sort,column=None) 返回类型pd.DataFrame或类型pd.Series
#         split_record(self,df: pd.DataFrame, sp_cloc: str, sign: str)返回类型pd.DataFrame
#         plus_record(self,dfp: pd.DataFrame, pr_cloc: str, sign: str)返回类型pd.DataFrame
#         split_period(self,df, start, end, interval)返回类型pd.DataFrame
#         plus_period(self,dfp: pd.DataFrame, s_date,e_date,pr_cloc: str, sign: str)返回类型pd.DataFrame
#
#     使用方法：
#         1.实例化
#         import pandas as pd
#         import pandasAnalysis as pa
#         df=pd.DataFrame(
#                         [
#                             ['A','B','C',pd.to_datetime('2020-12-31'),pd.to_datetime('2021-1-8'),'完成情况1'],
#                             ['D','E','F',pd.to_datetime('2021-2-26'),pd.to_datetime('2021-3-7'),'完成情况2'],
#                             ['C','E','F',pd.to_datetime('2021-1-20'),pd.to_datetime('2022-3-8'),'完成情况3'],
#                         ],columns=['编号','责任人','关键任务','开始日期','结束日期','完成情况'])
#         df_pa=pa.pandasAnalysis(df)
#         2.get_df(self)函数
#         获取df值，封装内部数据
#
#
#   编号          责任人 关键任务       开始日期       结束日期   完成情况
# 0  A     孔令、刘 媛媛     C 2020-12-31 2021-01-08  完成情况1
# 1  D  李 黎、李进 、昆 明    F 2021-02-26 2021-03-07  完成情况2
# 2  C          王 玺    F 2021-01-20 2022-03-08  完成情况3
#   编号          责任人 关键任务       开始日期       结束日期   完成情况
# 0  A     孔令、刘 媛媛     C 2020-12-31 2021-01-08  完成情况1
# 1  D  李 黎、李进 、昆 明    F 2021-02-26 2021-03-07  完成情况2
# 2  C          王 玺    F 2021-01-20 2022-03-08  完成情况3
#   编号          责任人 关键任务       开始日期       结束日期   完成情况
# 0  A     孔令、刘 媛媛     C 2020-12-31 2021-01-08  完成情况1
# 1  D  李 黎、李进 、昆 明    F 2021-02-26 2021-03-07  完成情况2
# 2  C          王 玺    F 2021-01-20 2022-03-08  完成情况3
#   编号          责任人 关键任务       开始日期       结束日期   完成情况
# 0  A      孔令、刘 媛媛    C 2020-12-31 2021-01-08  完成情况1
# 1  D  李 黎、李进 、昆 明    F 2021-02-26 2021-03-07  完成情况2
# 2  C          王 玺    F 2021-01-20 2022-03-08  完成情况3
#   编号       责任人 关键任务       开始日期       结束日期   完成情况
# 0  A    孔令、刘媛媛    C 2020-12-31 2021-01-08  完成情况1
# 1  D  李黎、李进、昆明    F 2021-02-26 2021-03-07  完成情况2
# 2  C        王玺    F 2021-01-20 2022-03-08  完成情况3
#   编号       责任人 关键任务       开始日期       结束日期   完成情况
# 1  D  李黎、李进、昆明    F 2021-02-26 2021-03-07  完成情况2
# 0  A    孔令、刘媛媛    C 2020-12-31 2021-01-08  完成情况1
# 2  C        王玺    F 2021-01-20 2022-03-08  完成情况3
#   编号  责任人 关键任务       开始日期       结束日期   完成情况
# 0  D   李黎    F 2021-02-26 2021-03-07  完成情况2
# 1  D   李进    F 2021-02-26 2021-03-07  完成情况2
# 2  D   昆明    F 2021-02-26 2021-03-07  完成情况2
# 3  A   孔令    C 2020-12-31 2021-01-08  完成情况1
# 4  A  刘媛媛    C 2020-12-31 2021-01-08  完成情况1
# 5  C   王玺    F 2021-01-20 2022-03-08  完成情况3
#   编号       责任人 关键任务       开始日期       结束日期   完成情况
# 0  A    孔令，刘媛媛    C 2020-12-31 2021-01-08  完成情况1
# 1  C        王玺    F 2021-01-20 2022-03-08  完成情况3
# 2  D  李黎，李进，昆明    F 2021-02-26 2021-03-07  完成情况2
#   编号 责任人 关键任务       开始日期       结束日期   完成情况
# 0  A   B    C 2020-12-31 2021-01-08  完成情况1
# 1  D   E    F 2021-02-26 2021-03-07  完成情况2
# 2  C   E    F 2021-01-20 2022-03-08  完成情况3
#    编号 责任人 关键任务       开始日期       结束日期   完成情况
# 0   A   B    C 2020-12-31 2020-12-31  完成情况1
# 1   A   B    C 2021-01-01 2021-01-08  完成情况1
# 2   D   E    F 2021-02-26 2021-02-28  完成情况2
# 3   D   E    F 2021-03-01 2021-03-07  完成情况2
# 4   C   E    F 2021-01-20 2021-01-31  完成情况3
# 5   C   E    F 2021-02-01 2021-02-28  完成情况3
# 6   C   E    F 2021-03-01 2021-03-31  完成情况3
# 7   C   E    F 2021-04-01 2021-04-30  完成情况3
# 8   C   E    F 2021-05-01 2021-05-31  完成情况3
# 9   C   E    F 2021-06-01 2021-06-30  完成情况3
# 10  C   E    F 2021-07-01 2021-07-31  完成情况3
# 11  C   E    F 2021-08-01 2021-08-31  完成情况3
# 12  C   E    F 2021-09-01 2021-09-30  完成情况3
# 13  C   E    F 2021-10-01 2021-10-31  完成情况3
# 14  C   E    F 2021-11-01 2021-11-30  完成情况3
# 15  C   E    F 2021-12-01 2021-12-31  完成情况3
# 16  C   E    F 2022-01-01 2022-01-31  完成情况3
# 17  C   E    F 2022-02-01 2022-02-28  完成情况3
# 18  C   E    F 2022-03-01 2022-03-08  完成情况3
#   编号 责任人 关键任务       开始日期       结束日期  \
# 0  A   B    C 2020-12-31 2021-01-08
# 1  C   E    F 2021-01-20 2022-03-08
# 2  D   E    F 2021-02-26 2021-03-07
#
#                                                 完成情况
# 0                                        完成情况1；完成情况1
# 1  完成情况3；完成情况3；完成情况3；完成情况3；完成情况3；完成情况3；完成情况3；完成情况...
# 2                                        完成情况2；完成情况2
# <bound method NDFrame.head of    一、主保护、稳控装置拒动导致电网稳定破坏风险                                         Unnamed: 1  \
# 0                    风险序号                                               风险描述
# 1                       1  （承接省调）500kV宝峰、圭山、七甸以及220kV松茂、嵩明、雨树变220kV母线发生单相...
# 2                       2  （承接省调）新老草铺、宝峰、厂口、圭山、庄乔、七甸、白邑7个厂站500kV母线若发生三相短路...
# 3                       3  承接省调）直流闭锁若稳控拒动，将导致严重的高频问题，将导致云南高频切机动作，若第三道防线无法...
# 4                       4  （承接省调）黄坪区域、仁和区域稳控系统拒动，滇西北电厂功角失稳，失步解列将大理、保山、丽江、...
# 5                       5           东郊区域稳控系统拒动，将导致设备过载，严重情况下引发连锁故障，存在一般事故风险。
# 6                     NaN                                                NaN
# 7                    措施序号                                               归口部门
# 8                       1                                                生技部
# 9                       2                                                NaN
# 10                      3                                                NaN
# 11                      4                                                NaN
# 12                      5                                                NaN
# 13                      6                                                NaN
# 14                      7                                                NaN
# 15                    NaN                                                NaN
# 16                      8                                                NaN
# 17                      9                                                NaN
# 18                     10                                                系统部
# 19                     11                                                NaN
# 20                     12                                                NaN
# 21                     13                                                NaN
# 22                     14                                                NaN
# 23                     15                                                NaN
#
#    Unnamed: 2                                         Unnamed: 3  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4         NaN                                                NaN
# 5         NaN                                                NaN
# 6         NaN                                                NaN
# 7        任务类别                                               分解措施
# 8        运行维护  落实《云南电网公司提升站用交直流电源设备健康水平专项行动方案》和《变电站直流电源系统运维管理...
# 9        作业管理  严格按照《云南电网有限责任公司输变电生产作业管理业务指导书（2020版）》及《云南电网公司2...
# 10        NaN                                                NaN
# 11       检修预试          落实《电力设备检修试验规程》“应修必修、应试必试”要求，避免设备超期未检未试隐患。
# 12        NaN                                                NaN
# 13        NaN                                                NaN
# 14       隐患排查  1、按期完成设备反事故措施、家族性缺陷隐患整改工作。\n2、按照《昆明供电局电力设施外力破坏...
# 15        NaN                                               None
# 16        NaN                                    配合开展2021年谐波普测工作
# 17       大修技改                                         完成老旧直流系统改造
# 18       大修技改                            按年度计划做好关键站点安稳、保护设备技改工作。
# 19        NaN                                                NaN
# 20        NaN                                                NaN
# 21       二次运维  按年度计划开展关键站点二次设备运维工作。正常维护方面做好定检及缺陷处理工作；特别维护方面将关...
# 22        NaN                                                NaN
# 23       隐患排查                                   按年度计划开展关键站点隐患整改。
#
#       Unnamed: 4           Unnamed: 5  \
# 0            NaN                  NaN
# 1            NaN                  NaN
# 2            NaN                  NaN
# 3            NaN                  NaN
# 4            NaN                  NaN
# 5            NaN                  NaN
# 6            NaN                  NaN
# 7        管控\n风险点                 完成时间
# 8   风险点1、2、3、4、5  2021-12-31 00:00:00
# 9         风险点1、2  2021-12-31 00:00:00
# 10           NaN                 None
# 11        风险点1、2  2021-12-31 00:00:00
# 12           NaN                 None
# 13           NaN                 None
# 14        风险点1、2  2021-12-31 00:00:00
# 15          None                 None
# 16  风险点1、2、3、4、5                 None
# 17          风险点2  2021-12-31 00:00:00
# 18        风险点1、2  2021-06-30 00:00:00
# 19           NaN  2021-12-01 00:00:00
# 20      风险点3、4、5  2021-12-01 00:00:00
# 21  风险点1、2、3、4、5  2021-12-31 00:00:00
# 22           NaN  2021-06-01 00:00:00
# 23        风险点1、2  2021-12-01 00:00:00
#
#                                            Unnamed: 6
# 0                                              重点关注设备
# 1           500kV宝峰、圭山、七甸以及220kV松茂、嵩明、雨树变220kV母线及其主保护
# 2   500kV七甸、草铺、宝峰、厂口、庄乔、圭山、白邑变、220kV赤鹫、樟木箐、中屏变相关50...
# 3                                     500kV宝峰、白邑变安稳装置
# 4                                   500kV厂口变安稳装置（监测站）
# 5                  220kV东郊变、果林变、大板桥变、西冲变、雨龙变、茨坝变稳控装置。
# 6                                                 NaN
# 7                                            责任单位关键项目
# 8   变电运行一所：\n1.将500kV宝峰变、500kV圭山变、500kV七甸变、500kV庄乔...
# 9   变电运行一所：\n1.涉及关键厂站母线倒闸操作，必须安排管理人员到位，管理人员提前核实班组操...
# 10  变电运行二所：\n1.涉及关键厂站母线倒闸操作，必须安排管理人员到位，管理人员提前核实班组操...
# 11  变电运行一所：\n1.2月28日前清理500kV宝峰变、500kV圭山变、500kV七甸变、...
# 12  变电运行二所：\n1.2月28日前清理500kV草铺变、500kV厂口变、220kV赤鹫变、...
# 13  变电修试所：\n1、按照《电力设备检修试验规程》、《继电保护设备检验规程》要求，结合2021...
# 14  变电运行一所：\n1.持续跟踪500kV圭山变周边违章建筑隐患，及时向局有关部门上报。\n2...
# 15  变电运行二所：\n做好500kV草铺变、500kV厂口变、220kV赤鹫变、220kV中屏变...
# 16  变电运行一、二所、修试所：\n针对2020年全网谐波普查发现的厂站超标问题，按计划配合落实整...
# 17       规划建设管理中心（质监分站）：\n完成220kV樟木箐变、220kV中屏变直流系统改造。
# 18        变电修试所：\n6月完成500kV宝峰、厂口变220kV母线保护双母差双失灵改造工作。
# 19  变电修试所：\n1.12月完成500kV草铺变500kV母线保护更换工作。\n2.12月完成...
# 20  电力调度控制中心、变电修试所：\n1.结合OCS系统保信模块的建设，完成安自模块功能试点建设...
# 21  变电修试所：\n1.按照重点维护策略，12月完成500kV宝峰、圭山、七甸、草铺、厂口、庄乔...
# 22  变电运行一所：\n1.6月完成500kV宝峰、白邑变、220kV东郊、果林变、110kV大板...
# 23  变电修试所：\n1.按计划完成晋城、吴家营智能站改造，6月完成220kV松茂、嵩明、赤鹫、中...  >

# %% [markdown]
# # 数据清洗

# %%
 def cleaning(self):
        # 删除重复值
        self.df.drop_duplicates(inplace=True)
        # 删除缺失值
        self.df.dropna(axis=0, how='all', inplace=True)

# %% [markdown]
# # 按照指定顺序进行排序

# %%
import pandas as pd
def sort_list(obj,list_sort,column=None):
    if isinstance(obj,pd.Series):        
        df=pd.DataFrame(obj)
        df = df.reset_index()
        df.columns = ['index', 'values']
        df1=df[df['index'].isin(list_sort)].copy()
        df2=df[~df['index'].isin(list_sort)].copy()
        df1['index']=df1['index'].astype('category')
        df1['index'].cat.set_categories(list_sort, inplace=True)
        df1.sort_values('index', ascending=True, inplace=True) 
        df=pd.concat([df1,df2])
        object_ = pd.Series(df['values'].values,index = df['index'])
    elif isinstance(obj,pd.DataFrame):
        obj1=obj[obj[column].isin(list_sort)].copy()
        obj2=obj[~obj[column].isin(list_sort)].copy()
        obj1[column]=obj1[column].astype('category')
        obj1[column].cat.set_categories(list_sort, inplace=True)
        object_=obj1.sort_values(column, ascending=True)
        object_=pd.concat([object_,obj2])
    return object_
if __name__ == '__main__':
    data=['A','B','C']
    index=[0,1,2]
    s=pd.Series(data,index)
    list_sort=[2,1,0,3]
    print(sort_list(s,list_sort))
    data=['A','B','C']
    list_sort=['B','C','A']
    df=pd.DataFrame(
        [
            ['A','B','C'],
            ['D','E','F'],
            ['C','E','F'],
        ]
        ,columns=['一','二','三'])
    print(df)
    print(sort_list(df,list_sort,'一'))
# Out:
# index
# 2    C
# 1    B
# 0    A
# dtype: object
#    一  二  三
# 0  A  B  C
# 1  D  E  F
# 2  C  E  F
#    一  二  三
# 2  C  E  F
# 0  A  B  C
# 1  D  E  F

# %%
import pandas as pd
import time
from dateutil.relativedelta import relativedelta
import datetime
import calendar
from dateutil import rrule



def get_n_day(date_time, n=1, m=0):
    # this_month_start = datetime.datetime(self.date_time.year, self.date_time.month, 1)
    this_month_nday = datetime.datetime(date_time.year, date_time.month, n)  # +datetime.timedelta(days=n)
    this_month_end = datetime.datetime(date_time.year, date_time.month,
                                       calendar.monthrange(date_time.year, date_time.month)[1])
    # n_month_start=this_month_start +relativedelta(months=m)
    n_month_end = this_month_end + relativedelta(months=m)
    n_month_nday = this_month_nday + relativedelta(months=m)
    return n_month_nday, n_month_end

def get_current_week(date_time, n=1,w=0):
    monday, sunday = date_time, date_time
    one_day = datetime.timedelta(days=1)
    while monday.weekday() != 0:
        monday -= one_day
    while sunday.weekday() != 6:
        sunday += one_day
    # 返回当前的星期一和星期天的日期
    week_n = monday + datetime.timedelta(days=n)
    n_week_end = sunday + relativedelta(weeks=w)
    n_week_nday = week_n + relativedelta(weeks=w)
    return n_week_nday,n_week_end


def p_split(df, start, end, interval):
    #重置df.index，保证后面编号不覆盖。
    df=df.reset_index(drop=True)
    #确定有几行
    df_scope = len(df)
    #遍历所有行
    for i in range(df_scope):
        #判断时间行是时间类型
        if isinstance(df[start][i], datetime.datetime) and isinstance(df[end][i],datetime.datetime):
            #将开始时间行赋值给变量d_start;结束时间赋值给d_end。
            d_start = df[start][i]
            d_end = df[end][i]
            #判断间隔值是m——月；w——月；d——日
            if interval == 'm':                                    
                delta = rrule.rrule(rrule.MONTHLY, dtstart=d_start, until=d_end).count()
                #解决跨月问题只要月份不同就判定为跨月
                if get_n_day(df[start][i],m=delta-1)[1]< df[end][i]:
                    delta=delta+1
                loop_delta = 0
                if delta > 1:
                    loop_delta = delta
                    for j in range(loop_delta):
                        df_scope = j + df_scope
                        df.loc[df_scope] = df.loc[i]
                        #this_month_start,this_month_end = get_n_day(df[start][df_scope])   
                        if j == 0:                            
                            df.loc[df_scope, end] = get_n_day(df[start][df_scope])[1]
                        elif j == loop_delta-1:
                            df.loc[df_scope, start] = get_n_day(df[start][df_scope],m=j)[0]
                        else:
                            df.loc[df_scope, start],df.loc[df_scope, end] = get_n_day(df[start][df_scope],m=j)

                    df.drop(index=[i], inplace=True)
                df_scope = df_scope + 1
             #判断间隔值是m——月；w——周；d——日
            if interval == 'w':
                delta = rrule.rrule(rrule.WEEKLY, dtstart=d_start, until=d_end).count()
                #解决跨周问题,关键点是开始日期所在周推delta个周后的周末是否小于end日期              
                if get_current_week(df[start][i], w=delta-1)[1]< df[end][i]:
                    delta=delta+1
                else:
                    pass               
                               
                loop_delta = 0
                if delta > 1:
                    loop_delta = delta
                    for j in range(loop_delta):
                        df_scope = j + df_scope
                        df.loc[df_scope] = df.loc[i]
                        this_week_start,this_week_end= get_current_week(df[start][df_scope])
                        if j == 0:                            
                            df.loc[df_scope, end ] = this_week_end
                        elif j == loop_delta-1:
                            df.loc[df_scope, start] = get_current_week(df[start][df_scope],w=j)[0]
                                                 

                        else:
                            df.loc[df_scope, start],df.loc[df_scope, end]= get_current_week(df[start][df_scope],w=j)
                           
                    df.drop(index=[i], inplace=True)
                df_scope = df_scope + 1
            if interval == 'd':
                delta = rrule.rrule(rrule.DAILY, dtstart=d_start, until=d_end).count()
                loop_delta = 0
                if delta > 1:
                    loop_delta = delta
                    for j in range(loop_delta):
                        df_scope = j + df_scope
                        df.loc[df_scope] = df.loc[i]
                        df.loc[df_scope, start] = d_start + relativedelta(days=+j)
                        df.loc[df_scope, end] = d_start + relativedelta(days=+j)
                    df.drop(index=[i], inplace=True)
                df_scope = df_scope + 1
    df.reset_index(inplace=True,drop=True)
    return df

# 将某列以外都相同的行以','进行合并
def plus_period(dfp: pd.DataFrame, s_date,e_date,pr_cloc: str, sign: str):
    # 获取dfp的列名
    list_cl = list(dfp)
    # 去除需要合并列的列名
    list_cl.remove(s_date)
    list_cl.remove(e_date)
    list_cl.remove(pr_cloc)
    print(list_cl)
    # 按照去除合并列名进行排序
    dfp.sort_values(list_cl, inplace=True)
    # 按照排序后行，重新设置index
    dfp = dfp.reset_index(drop=True)
    # 复制dfp，用以处理
    dfpc = dfp.copy()
    # 去除合并列
    dfpc.drop([s_date,e_date,pr_cloc], axis=1, inplace=True)
    # 进行查重处理
    list_dp = dfpc.duplicated()
    # 查找重复分界点
    x = list_dp[list_dp.isin([False])].index
    # 因为没有找到index插入的方法，将分界点index转为list
    list_x = []
    for q in range(len(x)):
        list_x.append(x[q])
    # 主要用于加入最后一条记录index
    list_x.append(len(dfp))

    # print(list_x)
    # x.append(int64(len(dfp)))
    yn = []
    # 循环获取重复记录段数据
    for i in range(len(list_x) - 1):
        # 判断是否有需要合并项
        if (list_x[i + 1] - list_x[i]) > 1:
            # 若有序号间隔大于1，则进入循环

            for j in range(list_x[i + 1] - list_x[i]):
                # 取出需要合并数据，形成list
                yn.append(dfp.loc[list_x[i] + j, pr_cloc])
            # 将list合并成以sign为分隔字符串。
            y = sign.join(yn)
            print(y)
            #排序
            dfp_d=dfp.loc[list_x[i]:list_x[i+1]-1,:].copy()            
            dfp_d.sort_values(s_date, inplace=True)
            dfp_d.reset_index(drop=True,inplace=True)
            # 将字符串赋给dfp第一列
            dfp.loc[list_x[i], pr_cloc] = y
            dfp.loc[list_x[i], s_date] = dfp_d.loc[0, s_date]
            dfp.loc[list_x[i], e_date] = dfp_d.loc[list_x[i + 1] - list_x[i]-1, e_date]
            
            # 删除多余项目
            for k in range(list_x[i + 1] - list_x[i] - 1):
                dfp.drop(list_x[i] + 1 + k, axis=0, inplace=True)
            # 清空记录list
            yn = []
    # 重置index
    dfp = dfp.reset_index(drop=True)

    return dfp
if __name__ == '__main__':
    df=pd.DataFrame(
    [
        ['A','B','C',pd.to_datetime('2020-12-31'),pd.to_datetime('2021-1-8')],
        ['D','E','F',pd.to_datetime('2021-2-26'),pd.to_datetime('2021-3-7')],
        ['C','E','F',pd.to_datetime('2021-1-20'),pd.to_datetime('2022-3-8')],
    ]
    ,columns=['一','二','三','开始日期','结束日期'])
    print(df)
    df1=p_split(df, '开始日期', '结束日期', 'm')
    print(df1)
    df2=plus_period(df1, '开始日期', '结束日期','三', '；')
    print(df2)
# Out:
#    一  二  三       开始日期       结束日期
# 0  A  B  C 2020-12-31 2021-01-08
# 1  D  E  F 2021-02-26 2021-03-07
# 2  C  E  F 2021-01-20 2022-03-08
#     一  二  三       开始日期       结束日期
# 0   A  B  C 2020-12-31 2020-12-31
# 1   A  B  C 2021-01-01 2021-01-08
# 2   D  E  F 2021-02-26 2021-02-28
# 3   D  E  F 2021-03-01 2021-03-07
# 4   C  E  F 2021-01-20 2021-01-31
# 5   C  E  F 2021-02-01 2021-02-28
# 6   C  E  F 2021-03-01 2021-03-31
# 7   C  E  F 2021-04-01 2021-04-30
# 8   C  E  F 2021-05-01 2021-05-31
# 9   C  E  F 2021-06-01 2021-06-30
# 10  C  E  F 2021-07-01 2021-07-31
# 11  C  E  F 2021-08-01 2021-08-31
# 12  C  E  F 2021-09-01 2021-09-30
# 13  C  E  F 2021-10-01 2021-10-31
# 14  C  E  F 2021-11-01 2021-11-30
# 15  C  E  F 2021-12-01 2021-12-31
# 16  C  E  F 2022-01-01 2022-01-31
# 17  C  E  F 2022-02-01 2022-02-28
# 18  C  E  F 2022-03-01 2022-03-08
# ['一', '二']
# C；C
# F；F；F；F；F；F；F；F；F；F；F；F；F；F；F
# F；F
#    一  二                              三       开始日期       结束日期
# 0  A  B                            C；C 2020-12-31 2021-01-08
# 1  C  E  F；F；F；F；F；F；F；F；F；F；F；F；F；F；F 2021-01-20 2022-03-08
# 2  D  E                            F；F 2021-02-26 2021-03-07

# %%
class nDay():
    '''
    此类用于获取给定日期所在月第一天和最后一天，或任意日的间隔一个月的开始和结束日期；
    实例变量只需要给定任意日期。
    the_n_day方法参数n为需要返回的开始日,m为需要返回的间隔月。
    例如：返回给定日期datetime所在月的第一天和最后一天
    d=nDay（datetime）
    d.the_n
    '''

    def __init__(self, date_time: datetime.datetime):
        self.date_time = date_time

    # 获取输入日期所在月份的第一天，最后一天和第n天，依据m可以是输入日期的前后n个月
    def get_n_day(self, n=1, m=0):
        # this_month_start = datetime.datetime(self.date_time.year, self.date_time.month, 1)
        this_month_nday = datetime.datetime(self.date_time.year, self.date_time.month, n)  # +datetime.timedelta(days=n)
        this_month_end = datetime.datetime(self.date_time.year, self.date_time.month,
                                           calendar.monthrange(self.date_time.year, self.date_time.month)[1])
        # n_month_start=this_month_start +relativedelta(months=m)
        n_month_end = this_month_end + relativedelta(months=m)
        n_month_nday = this_month_nday + relativedelta(months=m)

        return n_month_nday, n_month_end

    # 获取输入日期所在周的第一天，最后一天和第n天，依据m可以是输入日期的前后n个周
    def get_current_week(self, date_time, n):
        monday, sunday = date_time, date_time
        one_day = datetime.timedelta(days=1)
        while monday.weekday() != 0:
            monday -= one_day
        while sunday.weekday() != 6:
            sunday += one_day
        # 返回当前的星期一和星期天的日期
        week_n = monday + datetime.timedelta(days=n)

        return monday, sunday, week_n

# %%
import datetime
x=datetime.date(2017, 12, 31).isocalendar()
print(x[0],x[1])
# Out:
# 2017 52

# %%
import datetime
from dateutil import rrule
oneday = datetime.date(2020,12,26)

today = datetime.date(2021,1,8)
month = rrule.rrule(rrule.WEEKLY, dtstart=oneday, until=today).count()
print(month)
# Out:
# 2

# %%
import pandas as pd
class pandasAnalysis():
     # __doc__内容
    """
    作者：1979令狐冲
    E-mail：klmtldh@163.com
    
    pandas数据分析类
    类名称：pandasAnalysis
    函数：
        __init__(self,df)
        get_df(self) 返回类型pd.DataFrame
        cleaning(self,df,blank=None) 类返回型pd.DataFrame
        sort_list(self,obj,list_sort,column=None) 返回类型pd.DataFrame或类型pd.Series
        split_record(self,df: pd.DataFrame, sp_cloc: str, sign: str)返回类型pd.DataFrame
        plus_record(self,dfp: pd.DataFrame, pr_cloc: str, sign: str)返回类型pd.DataFrame
        split_period(self,df, start, end, interval)返回类型pd.DataFrame
        plus_period(self,dfp: pd.DataFrame, s_date,e_date,pr_cloc: str, sign: str)返回类型pd.DataFrame
        
    使用方法：
        1.实例化
        import pandas as pd
        import pandasAnalysis as pa
        df=pd.DataFrame(
                        [
                            ['A','B','C',pd.to_datetime('2020-12-31'),pd.to_datetime('2021-1-8'),'完成情况1'],
                            ['D','E','F',pd.to_datetime('2021-2-26'),pd.to_datetime('2021-3-7'),'完成情况2'],
                            ['C','E','F',pd.to_datetime('2021-1-20'),pd.to_datetime('2022-3-8'),'完成情况3'],
                        ],columns=['编号','责任人','关键任务','开始日期','结束日期','完成情况'])
        df_pa=pa.pandasAnalysis(df)
        2.get_df(self)函数
        获取df值，封装内部数据
        
    """
    def __init__(self,df):
        self.df=df
            
    def get_df(self):
        return self.df
   
    #数据清洗，主要删除重复值，删除缺失值，删除空格
    def cleaning(self,df,blank=None):
        # 删除重复值
        df.drop_duplicates(inplace=True)
        # 删除缺失值
        df.dropna(axis=0, how='all', inplace=True)
        # 删除空格
        if blank=='both':
            df=df.applymap((lambda x:str.strip(x) if type(x) is str else x))
        elif blank=='all':
            df=df.applymap((lambda x:"".join(x.split()) if type(x) is str else x))
        else:
            pass
        return df
    #按照指定列及list排序，可以实现Series和DataFrame,也可以实现排序list少数排序列的值。
    def sort_list(self,obj,list_sort,column=None):
        if isinstance(obj,pd.Series):
            df=pd.DataFrame(obj)
            df = df.reset_index()
            df.columns = ['index', 'values']
            df1=df[df['index'].isin(list_sort)].copy()
            df2=df[~df['index'].isin(list_sort)].copy()
            df1['index']=df1['index'].astype('category')
            df1['index'].cat.set_categories(list_sort, inplace=True)
            df1.sort_values('index', ascending=True, inplace=True)
            df=pd.concat([df1,df2])
            object_ = pd.Series(df['values'].values,index = df['index'])
        elif isinstance(obj,pd.DataFrame):
            obj1=obj[obj[column].isin(list_sort)].copy()
            obj2=obj[~obj[column].isin(list_sort)].copy()
            obj1[column]=obj1[column].astype('category')
            obj1[column].cat.set_categories(list_sort, inplace=True)
            object_=obj1.sort_values(column, ascending=True)
            object_=pd.concat([object_,obj2])
        return object_
    
    def split_record(self,df: pd.DataFrame, sp_cloc: str, sign: str):
        # 记录原始dataframe的长度，并作为后面追加数据的基准
        df.reset_index(inplace=True,drop=True)
        y = len(df)
        # 记录原始dataframe的长度
        len_df = len(df)
        for i in range(len(df)):
            # 将需要分列的列数据按照sign分列出来
            #print(i,df.loc[i, sp_cloc])
            list_str = str.split(df.loc[i, sp_cloc], sign)
            # 依据分列出来数据增加行
            for j in range(len(list_str)):
                y = y + j
                # 复制i行数据
                df.loc[y] = df.loc[i]
                # 将y行数据sp_cloc列数据设置为list_str中数据
                df.loc[y, sp_cloc] = list_str[j]
            y = y + 1
        # 取出新增加数据
        df = df.tail(len(df) - len_df)
        # 重置index
        df = df.reset_index(drop=True)
        return df


    # 将某列以外都相同的行以','进行合并
    def plus_record(self,dfp: pd.DataFrame, pr_cloc: str, sign: str):
        # 获取dfp的列名
        list_cl = list(dfp)
        # 去除需要合并列的列名
        list_cl.remove(pr_cloc)
        # 按照去除合并列名进行排序
        dfp.sort_values(list_cl, inplace=True)
        # 按照排序后行，重新设置index
        dfp = dfp.reset_index(drop=True)
        # 复制dfp，用以处理
        dfpc = dfp.copy()
        # 去除合并列
        dfpc.drop([pr_cloc], axis=1, inplace=True)
        # 进行查重处理
        list_dp = dfpc.duplicated()
        # 查找重复分界点
        x = list_dp[list_dp.isin([False])].index
        # 因为没有找到index插入的方法，将分界点index转为list
        list_x = []
        for q in range(len(x)):
            list_x.append(x[q])
        # 主要用于加入最后一条记录index
        list_x.append(len(dfp))

        # print(list_x)
        # x.append(int64(len(dfp)))
        yn = []
        # 循环获取重复记录段数据
        for i in range(len(list_x) - 1):
            # 判断是否有需要合并项
            if (list_x[i + 1] - list_x[i]) > 1:
                # 若有序号间隔大于1，则进入循环
                for j in range(list_x[i + 1] - list_x[i]):
                    # 取出需要合并数据，形成list
                    yn.append(dfp.loc[list_x[i] + j, pr_cloc])
                # 将list合并成以sign为分隔字符串。
                y = sign.join(yn)
                # 将字符串赋给dfp第一列
                dfp.loc[list_x[i], pr_cloc] = y
                # 删除多余项目
                for k in range(list_x[i + 1] - list_x[i] - 1):
                    dfp.drop(list_x[i] + 1 + k, axis=0, inplace=True)
                # 清空记录list
                yn = []
        # 重置index
        dfp = dfp.reset_index(drop=True)

        return dfp

    def get_n_day(self,date_time, n=1, m=0):
        # this_month_start = datetime.datetime(self.date_time.year, self.date_time.month, 1)
        this_month_nday = datetime.datetime(date_time.year, date_time.month, n)  # +datetime.timedelta(days=n)
        this_month_end = datetime.datetime(date_time.year, date_time.month,
                                           calendar.monthrange(date_time.year, date_time.month)[1])
        # n_month_start=this_month_start +relativedelta(months=m)
        n_month_end = this_month_end + relativedelta(months=m)
        n_month_nday = this_month_nday + relativedelta(months=m)
        return n_month_nday, n_month_end

    def get_current_week(self,date_time, n=1,w=0):
        monday, sunday = date_time, date_time
        one_day = datetime.timedelta(days=1)
        while monday.weekday() != 0:
            monday -= one_day
        while sunday.weekday() != 6:
            sunday += one_day
        # 返回当前的星期一和星期天的日期
        week_n = monday + datetime.timedelta(days=n)
        n_week_end = sunday + relativedelta(weeks=w)
        n_week_nday = week_n + relativedelta(weeks=w)
        return n_week_nday,n_week_end


    def split_period(self,df, start, end, interval):
        #重置df.index，保证后面编号不覆盖。
        df=df.reset_index(drop=True)
        #确定有几行
        df_scope = len(df)
        #遍历所有行
        for i in range(df_scope):
            #判断时间行是时间类型
            if isinstance(df[start][i], datetime.datetime) and isinstance(df[end][i],datetime.datetime):
                #将开始时间行赋值给变量d_start;结束时间赋值给d_end。
                d_start = df[start][i]
                d_end = df[end][i]
                #判断间隔值是m——月；w——月；d——日
                if interval == 'm':                                    
                    delta = rrule.rrule(rrule.MONTHLY, dtstart=d_start, until=d_end).count()
                    #解决跨月问题只要月份不同就判定为跨月
                    if self.get_n_day(df[start][i],m=delta-1)[1]< df[end][i]:
                        delta=delta+1
                    loop_delta = 0
                    if delta > 1:
                        loop_delta = delta
                        for j in range(loop_delta):
                            df_scope = j + df_scope
                            df.loc[df_scope] = df.loc[i]
                            #this_month_start,this_month_end = get_n_day(df[start][df_scope])   
                            if j == 0:                            
                                df.loc[df_scope, end] = self.get_n_day(df[start][df_scope])[1]
                            elif j == loop_delta-1:
                                df.loc[df_scope, start] = self.get_n_day(df[start][df_scope],m=j)[0]
                            else:
                                df.loc[df_scope, start],df.loc[df_scope, end] = self.get_n_day(df[start][df_scope],m=j)
                        df.drop(index=[i], inplace=True)
                    df_scope = df_scope + 1
                 #判断间隔值是m——月；w——周；d——日
                if interval == 'w':
                    delta = rrule.rrule(rrule.WEEKLY, dtstart=d_start, until=d_end).count()
                    #解决跨周问题,关键点是开始日期所在周推delta个周后的周末是否小于end日期              
                    if self.get_current_week(df[start][i], w=delta-1)[1]< df[end][i]:
                        delta=delta+1
                    else:
                        pass               

                    loop_delta = 0
                    if delta > 1:
                        loop_delta = delta
                        for j in range(loop_delta):
                            df_scope = j + df_scope
                            df.loc[df_scope] = df.loc[i]
                            if j == 0:                            
                                df.loc[df_scope, end ] = self.get_current_week(df[start][df_scope])[1]
                            elif j == loop_delta-1:
                                df.loc[df_scope, start] = self.get_current_week(df[start][df_scope],w=j)[0]


                            else:
                                df.loc[df_scope, start],df.loc[df_scope, end]= self.get_current_week(df[start][df_scope],w=j)

                        df.drop(index=[i], inplace=True)
                    df_scope = df_scope + 1
                if interval == 'd':
                    delta = rrule.rrule(rrule.DAILY, dtstart=d_start, until=d_end).count()
                    loop_delta = 0
                    if delta > 1:
                        loop_delta = delta
                        for j in range(loop_delta):
                            df_scope = j + df_scope
                            df.loc[df_scope] = df.loc[i]
                            df.loc[df_scope, start] = d_start + relativedelta(days=+j)
                            df.loc[df_scope, end] = d_start + relativedelta(days=+j)
                        df.drop(index=[i], inplace=True)
                    df_scope = df_scope + 1
        df.reset_index(inplace=True,drop=True)
        return df

    # 将某列以外都相同的行,按照时间','进行合并
    def plus_period(self,dfp: pd.DataFrame, s_date,e_date,pr_cloc: str, sign: str):
        # 获取dfp的列名
        list_cl = list(dfp)
        # 去除需要合并列的列名
        list_cl.remove(s_date)
        list_cl.remove(e_date)
        list_cl.remove(pr_cloc)       
        # 按照去除合并列名进行排序
        dfp.sort_values(list_cl, inplace=True)
        # 按照排序后行，重新设置index
        dfp = dfp.reset_index(drop=True)
        # 复制dfp，用以处理
        dfpc = dfp.copy()
        # 去除合并列
        dfpc.drop([s_date,e_date,pr_cloc], axis=1, inplace=True)
        # 进行查重处理
        list_dp = dfpc.duplicated()
        # 查找重复分界点
        x = list_dp[list_dp.isin([False])].index
        # 因为没有找到index插入的方法，将分界点index转为list
        list_x = []
        for q in range(len(x)):
            list_x.append(x[q])
        # 主要用于加入最后一条记录index
        list_x.append(len(dfp))

        # print(list_x)
        # x.append(int64(len(dfp)))
        yn = []
        # 循环获取重复记录段数据
        for i in range(len(list_x) - 1):
            # 判断是否有需要合并项
            if (list_x[i + 1] - list_x[i]) > 1:
                # 若有序号间隔大于1，则进入循环

                for j in range(list_x[i + 1] - list_x[i]):
                    # 取出需要合并数据，形成list
                    yn.append(dfp.loc[list_x[i] + j, pr_cloc])
                # 将list合并成以sign为分隔字符串。
                y = sign.join(yn)               
                #排序
                dfp_d=dfp.loc[list_x[i]:list_x[i+1]-1,:].copy()            
                dfp_d.sort_values(s_date, inplace=True)
                dfp_d.reset_index(drop=True,inplace=True)
                # 将字符串赋给dfp第一列
                dfp.loc[list_x[i], pr_cloc] = y
                dfp.loc[list_x[i], s_date] = dfp_d.loc[0, s_date]
                dfp.loc[list_x[i], e_date] = dfp_d.loc[list_x[i + 1] - list_x[i]-1, e_date]

                # 删除多余项目
                for k in range(list_x[i + 1] - list_x[i] - 1):
                    dfp.drop(list_x[i] + 1 + k, axis=0, inplace=True)
                # 清空记录list
                yn = []
        # 重置index
        dfp = dfp.reset_index(drop=True)

        return dfp
    
    
if __name__ == '__main__':
    
    path=r"D:\JGY\300-Work工作\320-PM项目管理\电网年度运行方式\2021年昆明电网八大运行风险防控措施分解表（审查稿).xlsx"
    df_risk=pd.read_excel(path,'一、主保护、稳控装置拒动导致电网稳定破坏风险',engine="openpyxl")
    print(df_risk.head)
# Out:
# <bound method NDFrame.head of    一、主保护、稳控装置拒动导致电网稳定破坏风险                                         Unnamed: 1  \
# 0                    风险序号                                               风险描述
# 1                       1  （承接省调）500kV宝峰、圭山、七甸以及220kV松茂、嵩明、雨树变220kV母线发生单相...
# 2                       2  （承接省调）新老草铺、宝峰、厂口、圭山、庄乔、七甸、白邑7个厂站500kV母线若发生三相短路...
# 3                       3  承接省调）直流闭锁若稳控拒动，将导致严重的高频问题，将导致云南高频切机动作，若第三道防线无法...
# 4                       4  （承接省调）黄坪区域、仁和区域稳控系统拒动，滇西北电厂功角失稳，失步解列将大理、保山、丽江、...
# 5                       5           东郊区域稳控系统拒动，将导致设备过载，严重情况下引发连锁故障，存在一般事故风险。
# 6                     NaN                                                NaN
# 7                    措施序号                                               归口部门
# 8                       1                                                生技部
# 9                       2                                                NaN
# 10                      3                                                NaN
# 11                      4                                                NaN
# 12                      5                                                NaN
# 13                      6                                                NaN
# 14                      7                                                NaN
# 15                    NaN                                                NaN
# 16                      8                                                NaN
# 17                      9                                                NaN
# 18                     10                                                系统部
# 19                     11                                                NaN
# 20                     12                                                NaN
# 21                     13                                                NaN
# 22                     14                                                NaN
# 23                     15                                                NaN
#
#    Unnamed: 2                                         Unnamed: 3  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4         NaN                                                NaN
# 5         NaN                                                NaN
# 6         NaN                                                NaN
# 7        任务类别                                               分解措施
# 8        运行维护  落实《云南电网公司提升站用交直流电源设备健康水平专项行动方案》和《变电站直流电源系统运维管理...
# 9        作业管理  严格按照《云南电网有限责任公司输变电生产作业管理业务指导书（2020版）》及《云南电网公司2...
# 10        NaN                                                NaN
# 11       检修预试          落实《电力设备检修试验规程》“应修必修、应试必试”要求，避免设备超期未检未试隐患。
# 12        NaN                                                NaN
# 13        NaN                                                NaN
# 14       隐患排查  1、按期完成设备反事故措施、家族性缺陷隐患整改工作。\n2、按照《昆明供电局电力设施外力破坏...
# 15        NaN                                               None
# 16        NaN                                    配合开展2021年谐波普测工作
# 17       大修技改                                         完成老旧直流系统改造
# 18       大修技改                            按年度计划做好关键站点安稳、保护设备技改工作。
# 19        NaN                                                NaN
# 20        NaN                                                NaN
# 21       二次运维  按年度计划开展关键站点二次设备运维工作。正常维护方面做好定检及缺陷处理工作；特别维护方面将关...
# 22        NaN                                                NaN
# 23       隐患排查                                   按年度计划开展关键站点隐患整改。
#
#       Unnamed: 4           Unnamed: 5  \
# 0            NaN                  NaN
# 1            NaN                  NaN
# 2            NaN                  NaN
# 3            NaN                  NaN
# 4            NaN                  NaN
# 5            NaN                  NaN
# 6            NaN                  NaN
# 7        管控\n风险点                 完成时间
# 8   风险点1、2、3、4、5  2021-12-31 00:00:00
# 9         风险点1、2  2021-12-31 00:00:00
# 10           NaN                 None
# 11        风险点1、2  2021-12-31 00:00:00
# 12           NaN                 None
# 13           NaN                 None
# 14        风险点1、2  2021-12-31 00:00:00
# 15          None                 None
# 16  风险点1、2、3、4、5                 None
# 17          风险点2  2021-12-31 00:00:00
# 18        风险点1、2  2021-06-30 00:00:00
# 19           NaN  2021-12-01 00:00:00
# 20      风险点3、4、5  2021-12-01 00:00:00
# 21  风险点1、2、3、4、5  2021-12-31 00:00:00
# 22           NaN  2021-06-01 00:00:00
# 23        风险点1、2  2021-12-01 00:00:00
#
#                                            Unnamed: 6
# 0                                              重点关注设备
# 1           500kV宝峰、圭山、七甸以及220kV松茂、嵩明、雨树变220kV母线及其主保护
# 2   500kV七甸、草铺、宝峰、厂口、庄乔、圭山、白邑变、220kV赤鹫、樟木箐、中屏变相关50...
# 3                                     500kV宝峰、白邑变安稳装置
# 4                                   500kV厂口变安稳装置（监测站）
# 5                  220kV东郊变、果林变、大板桥变、西冲变、雨龙变、茨坝变稳控装置。
# 6                                                 NaN
# 7                                            责任单位关键项目
# 8   变电运行一所：\n1.将500kV宝峰变、500kV圭山变、500kV七甸变、500kV庄乔...
# 9   变电运行一所：\n1.涉及关键厂站母线倒闸操作，必须安排管理人员到位，管理人员提前核实班组操...
# 10  变电运行二所：\n1.涉及关键厂站母线倒闸操作，必须安排管理人员到位，管理人员提前核实班组操...
# 11  变电运行一所：\n1.2月28日前清理500kV宝峰变、500kV圭山变、500kV七甸变、...
# 12  变电运行二所：\n1.2月28日前清理500kV草铺变、500kV厂口变、220kV赤鹫变、...
# 13  变电修试所：\n1、按照《电力设备检修试验规程》、《继电保护设备检验规程》要求，结合2021...
# 14  变电运行一所：\n1.持续跟踪500kV圭山变周边违章建筑隐患，及时向局有关部门上报。\n2...
# 15  变电运行二所：\n做好500kV草铺变、500kV厂口变、220kV赤鹫变、220kV中屏变...
# 16  变电运行一、二所、修试所：\n针对2020年全网谐波普查发现的厂站超标问题，按计划配合落实整...
# 17       规划建设管理中心（质监分站）：\n完成220kV樟木箐变、220kV中屏变直流系统改造。
# 18        变电修试所：\n6月完成500kV宝峰、厂口变220kV母线保护双母差双失灵改造工作。
# 19  变电修试所：\n1.12月完成500kV草铺变500kV母线保护更换工作。\n2.12月完成...
# 20  电力调度控制中心、变电修试所：\n1.结合OCS系统保信模块的建设，完成安自模块功能试点建设...
# 21  变电修试所：\n1.按照重点维护策略，12月完成500kV宝峰、圭山、七甸、草铺、厂口、庄乔...
# 22  变电运行一所：\n1.6月完成500kV宝峰、白邑变、220kV东郊、果林变、110kV大板...
# 23  变电修试所：\n1.按计划完成晋城、吴家营智能站改造，6月完成220kV松茂、嵩明、赤鹫、中...  >

# %%
import pandas as pd
import numpy as np
def pandas_text(obj,drop_list=None,index_name=None,unit='项',punctuation=[',','。']):
    tx=''
    if isinstance(obj,pd.Series):        
        text = ''
        for i in range(len(obj)):
            if i != len(obj) - 1:
                text += str(obj.index[i]) +' '+ str(obj[i]) + unit + punctuation[0]
            else:
                text += str(obj.index[i])+' ' + str(obj[i]) + unit + punctuation[1]
        text=str(obj.name)+'：'+text
        tx=text
        
    if isinstance(obj,pd.DataFrame):
        text_list=[]
        if index_name is  None:
            
            for column in df.iteritems():
                if column[0] not in drop_list:
                    text = ''
                    for i in range(len(column[1])):
                        if i != len(column[1]) - 1:
                            text += str(column[1].index[i]) +' '+ str(column[1][i]) + unit + punctuation[0]
                        else:
                            text += str(column[1].index[i])+' ' + str(column[1][i]) + unit + punctuation[1]
                        #print('列名'+column[0],'\n',column[1])
                    text=str(column[1].name)+'：'+text
                    text_list.append(text)
        else:
            df.set_index(index_name,drop=True,inplace=True)
            for column in df.iteritems():
                if column[0] not in drop_list:
                    text = ''
                    for i in range(len(column[1])):
                        if i != len(column[1]) - 1:
                            text += str(column[1].index[i]) +' '+ str(column[1][i]) + unit + punctuation[0]
                        else:
                            text += str(column[1].index[i])+' ' + str(column[1][i]) + unit + punctuation[1]
                        #print('列名'+column[0],'\n',column[1])
                    text=str(column[1].name)+'：'+text
                    text_list.append(text)
            
            
        tx=text_list
    return tx

def null_item(df,all=1):
    null_ = df.isnull().sum()
    null_.sort_values(ascending=False, inplace=True)
    null_.name='空缺值'
    if all:        
        null_text = pandas_text(null_, '项')
    else:
        null_=null_[null_.values!=0].copy()
        null_text = pandas_text(null_, '项',punctuation=[',',','])+'其余数据完整。'
    return null_,null_text

def data_describe(obj):
    text="{}中共有{}条数据，每条数据有{}列，分别为：{}；其中,{}".format(obj.name,len(obj),len(list(df)),'、'.join(list(obj)),null_item(obj,0)[1])
    print(text)
    

if __name__ == '__main__':
    df=pd.DataFrame(
                    [
                        ['A',1,5,pd.to_datetime('2020-12-31'),pd.to_datetime('2021-1-8')],
                        ['D',np.nan,4,pd.to_datetime('2021-2-26'),pd.to_datetime('2021-3-7')],
                        ['C',3,np.nan,pd.to_datetime('2021-1-20'),pd.to_datetime('2022-3-8')],
                    ]
                    ,columns=['一','二','三','开始日期','结束日期']
                    )
    df.name='立行立改问题库'
    data_describe(df)
    df_null=null_item(df,0)
    print(df_null[1])
    df_null=null_item(df)
    print(df_null[1])
    
    print(pandas_text(df,['开始日期','结束日期'],'一'),'\n')
    #print(pandas_text(df_null[1]))

    path=r"D:\JGY\600-Data\002-in输入文件\个人\孔令手机通信录1.xlsx"
    df_risk=pd.read_excel(path,'Sheet1',engine="openpyxl")
    df_null=null_item(df_risk,0)
    print(df_null[1])
    df_null=null_item(df_risk,1)
    print(df_null[1])
# Out:
# 立行立改问题库中共有3条数据，每条数据有5列，分别为：一、二、三、开始日期、结束日期；其中,空缺值：二 1项,三 1项,其余数据完整。
# 空缺值：二 1项,三 1项,其余数据完整。
# 空缺值：二 1项,三 1项,一 0项,开始日期 0项,结束日期 0项。
# ['二：A 1.0项,D nan项,C 3.0项。', '三：A 5.0项,D 4.0项,C nan项。']
#
# 空缺值：家庭传真机 4099项,昵称 4099项,ICQ 4099项,谷歌 4099项,SKYPE 4099项,雅虎 4099项,JABBER 4099项,MSN 4098项,总机 4098项,互联网通话 4098项,寻呼机 4098项,AIM 4098项,单位传真机 4096项,工作电子邮箱 4093项,单位地址 4092项,家庭座机 4084项,QQ 4083项,个人电子邮箱 4022项,家庭住址 3920项,网站 3882项,单位座机 3624项,备注 2987项,生日 2505项,职务 1885项,单位 1062项,手机 62项,其余数据完整。
# 空缺值：家庭传真机 4099项,昵称 4099项,ICQ 4099项,谷歌 4099项,SKYPE 4099项,雅虎 4099项,JABBER 4099项,MSN 4098项,总机 4098项,互联网通话 4098项,寻呼机 4098项,AIM 4098项,单位传真机 4096项,工作电子邮箱 4093项,单位地址 4092项,家庭座机 4084项,QQ 4083项,个人电子邮箱 4022项,家庭住址 3920项,网站 3882项,单位座机 3624项,备注 2987项,生日 2505项,职务 1885项,单位 1062项,手机 62项,拼音 0项,姓名 0项,UID 0项,拼音声调 0项。
